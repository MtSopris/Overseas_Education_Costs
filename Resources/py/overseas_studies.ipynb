# %%
import pandas as pd
import numpy as np
from glob import glob, iglob
import pymongo
import json
import os

# %%
excel_path=os.path.join("../data",'OECDTuitionData.xlsx')
excel=pd.read_excel(excel_path)
tuition_df=pd.DataFrame(excel)
tuition_df
# Out:
#    Education at a Glance 2019: OECD Indicators - © OECD 2019  \
# 0                                                   C
# 1               Version 1 - Last updated: 02-Sep-2019
# 2                 Disclaimer: http://oe.cd/disclaimer
# 3                                                 NaN
# 4                                         Table C5.1.
# 5   Annual average (or most common) tuition fees c...
# 6   In equivalent USD converted using PPPs, by typ...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                          Countries
# 14                                          Australia
# 15                                            Austria
# ...

# %%
excel_path=os.path.join("../data",')penDoors-U.S.-Study-Abroad-Student-Profile.xlsx')
excel=pd.read_excel(excel_path)
USabroad_demogrph_df=pd.DataFrame(excel)
USabroad_demogrph_df
# Out:
#    PERCENT OF U.S. STUDY ABROAD STUDENTS BY FIELD OF STUDY, 2000/01 - 2018/19  \
# 0                                      Characteristic
# 1                                                 NaN
# 2                                                 NaN
# 3                                      Academic level
# 4                                       Undergraduate
# 5                                Associate's Students
# 6                                            Freshman
# 7                                           Sophomore
# 8                                              Junior
# 9                                              Senior
# 10                            Bachelor's, Unspecified
# 11                                           Graduate
# 12                                  Master's Students
# 13                             Graduate, Professional
# 14                                  Doctoral Students
# 15                              Graduate, Unspecified
# ...

# %%
csv_path=os.path.join("../data",'timesData.csv')
csv=pd.read_csv(csv_path)
rank_df=pd.DataFrame(csv)
rank_df.head(25)
# Out:
#    world_rank                                    university_name  \
# 0           1                                 Harvard University
# 1           2                 California Institute of Technology
# 2           3              Massachusetts Institute of Technology
# 3           4                                Stanford University
# 4           5                               Princeton University
# 5           6                            University of Cambridge
# 6           6                               University of Oxford
# 7           8                 University of California, Berkeley
# 8           9                            Imperial College London
# 9          10                                    Yale University
# 10         11              University of California, Los Angeles
# 11         12                              University of Chicago
# 12         13                           Johns Hopkins University
# ...

# %%
excel_path=os.path.join("../data",'U.S.-Study-Abroad-All-Destinations.xlsx')
excel=pd.read_excel(excel_path)
USabroadregion_df=pd.DataFrame(excel)
USabroadregion_df
# Out:
#      Unnamed: 0 DESTINATIONS OF U.S. STUDY ABROAD STUDENTS, 1999/00 -2018/19  \
# 0           NaN                                                NaN
# 1           NaN                                       Destinations
# 2           NaN                                                NaN
# 3        1000.0                                AFRICA, SUB-SAHARAN
# 4           NaN                   Africa, Sub-saharan, Unspecified
# ..          ...                                                ...
# 295         NaN  Note: Dash symbol (-) indicates no data availa...
# 296         NaN  Note: Regional names and data reflect Open Doo...
# 297         NaN  Windward Islands is included in Caribbean, Uns...
# 298         NaN                                                NaN
# 299         NaN  Suggested citation: Institute of International...
#
#      Unnamed: 2                  Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# ...

# %%
Census-All-Places-of-Origin-1.xlsx
excel_path=os.path.join("../data",'Census-All-Places-of-Origin-1.xlsx')
excel=pd.read_excel(excel_path)
study-origin_df=pd.DataFrame(excel)
USabroadregion_df
